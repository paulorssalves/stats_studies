# %%
miles_traveled = c(89, 66, 78, 111, 44, 77, 80, 66, 109, 76)
num_deliveries = c(4, 1, 3, 6, 1, 3, 3, 2, 5, 3)
gas_price = c(3.84, 3.19, 3.78, 3.89, 3.57, 3.57, 3.03, 3.51, 3.54, 3.25)
travel_time = c(7, 5.4, 6.6, 7.4, 4.8, 6.4, 7, 5.6, 7.3, 6.4)

d = lm(travel_time ~ miles_traveled)

# %%
sm = summary(d)
sm
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduzidos por coerção”
# Call:
# lm(formula = travel_time ~ miles_traveled)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0,4425 -0,2512 -0,0211  0,2124  0,5939
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    3,185560   0,466951   6,822 0,000135 ***
# miles_traveled 0,040257   0,005706   7,055 0,000107 ***
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 0,3423 on 8 degrees of freedom
# Multiple R-squared:  0,8615,	Adjusted R-squared:  0,8442
# F-statistic: 49,77 on 1 and 8 DF,  p-value: 0,0001067

# %%
plot(travel_time ~ miles_traveled)
abline(d)
# Out:
# plot without title

# %%
sm$sigma
# Out:
# [1] 0,3423088

# %%
sm$sigma
# sigma is the standard error of the regression
# Out:
# [1] 0.3423088

# %%
tn = lm (travel_time ~num_deliveries)

# %%
tn
# Out:
# Call:
# lm(formula = travel_time ~ num_deliveries)
#
# Coefficients:
#    (Intercept)  num_deliveries
#         4,8454          0,4983

# %%
plot(travel_time ~ num_deliveries)
abline(tn)
summary(tn)
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduzidos por coerção”
# Call:
# lm(formula = travel_time ~ num_deliveries)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0,54367 -0,19061  0,05808  0,13614  0,65983
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4,84541    0,26535  18,261 8,32e-08 ***
# num_deliveries  0,49825    0,07692   6,478 0,000193 ***
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 0,3681 on 8 degrees of freedom
# Multiple R-squared:  0,8399,	Adjusted R-squared:  0,8199
# F-statistic: 41,96 on 1 and 8 DF,  p-value: 0,0001926
# plot without title

# %%
k = summary(tn)
k
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduzidos por coerção”
# Call:
# lm(formula = travel_time ~ num_deliveries)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0,54367 -0,19061  0,05808  0,13614  0,65983
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4,84541    0,26535  18,261 8,32e-08 ***
# num_deliveries  0,49825    0,07692   6,478 0,000193 ***
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 0,3681 on 8 degrees of freedom
# Multiple R-squared:  0,8399,	Adjusted R-squared:  0,8199
# F-statistic: 41,96 on 1 and 8 DF,  p-value: 0,0001926

# %%
bk = k$coefficients
bk
# Out:
#                Estimate  Std. Error t value   Pr(>|t|)
# (Intercept)    4,8454148 0,26534529 18,260791 8,317403e-08
# num_deliveries 0,4982533 0,07691976  6,477572 1,926088e-04

# %%
summary(lm (travel_time ~ gas_price))$coefficients
# Out:
#             Estimate  Std. Error t value   Pr(>|t|)
# (Intercept) 3.5364882 3.649039   0.9691561 0.3608511
# gas_price   0.8113483 1.034477   0.7843074 0.4554534

# %%
summary(lm (travel_time ~ gas_price))
# Out:
# Call:
# lm(formula = travel_time ~ gas_price)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6330 -0.5518  0.1116  0.6175  1.0051
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.5365     3.6490   0.969    0.361
# gas_price     0.8113     1.0345   0.784    0.455
#
# Residual standard error: 0.8864 on 8 degrees of freedom
# Multiple R-squared:  0.0714,	Adjusted R-squared:  -0.04467
# F-statistic: 0.6151 on 1 and 8 DF,  p-value: 0.4555

# %%
get_regression_values <- function(indepvar, depvar) {
    return (summary(lm(depvar ~ indepvar)))
}

# %%
mtravel = lm(travel_time ~ miles_traveled + num_deliveries)

# %%
summary(mtravel)
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduzidos por coerção”
# Call:
# lm(formula = travel_time ~ miles_traveled + num_deliveries)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0,34711 -0,24290 -0,05702  0,17910  0,61792
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3,73216    0,88697   4,208    0,004 **
# miles_traveled  0,02622    0,02002   1,310    0,232
# num_deliveries  0,18404    0,25091   0,733    0,487
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 0,3526 on 7 degrees of freedom
# Multiple R-squared:  0,8714,	Adjusted R-squared:  0,8347
# F-statistic: 23,72 on 2 and 7 DF,  p-value: 0,0007627

# %%
library(caret)
# Out:
# Error in library(caret): there is no package called ‘caret’
# Traceback:
#
# 1. library(caret)
# 2. stop(txt, domain = NA)

# %%
car::vif
# Out:
# Error in loadNamespace(name): there is no package called ‘car’
# Traceback:
#
# 1. car::vif
# 2. getExportedValue(pkg, name)
# 3. asNamespace(ns)
# 4. getNamespace(ns)
# 5. tryCatch(loadNamespace(name), error = function(e) stop(e))
# 6. tryCatchList(expr, classes, parentenv, handlers)
# 7. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 8. value[[3L]](cond)

# %%
gt_travel = lm(travel_time ~ miles_traveled + gas_price)

# %%
gt_travel
# Out:
# Call:
# lm(formula = travel_time ~ miles_traveled + gas_price)
#
# Coefficients:
#    (Intercept)  miles_traveled       gas_price
#        3,86757         0,04137        -0,21912

# %%
summary(gt_travel)$coefficients
# Out:
#                Estimate    Std. Error  t value   Pr(>|t|)
# (Intercept)     3,86756989 1,482416074  2,608964 0,0349660156
# miles_traveled  0,04137042 0,006419456  6,444536 0,0003520833
# gas_price      -0,21912293 0,449410103 -0,487579 0,6407469290

# %%
cat("standard error: ",summary(gt_travel)$sigma)
# Out:
# standard error:  0,3598834

# %%
sm_gt = summary(gt_travel)
cat("R-squared: " ,sm_gt$r.squared, "\n")
cat("R-squared adjusted:", sm_gt$adj.r.squared, "\n")
# Out:
# R-squared:  0,866064
# R-squared adjusted: 0,8277966

# %%
ng_travel = lm ( travel_time ~ num_deliveries + gas_price)

# %%
ng_travel
# Out:
# Call:
# lm(formula = travel_time ~ num_deliveries + gas_price)
#
# Coefficients:
#    (Intercept)  num_deliveries       gas_price
#         7,3243          0,5665         -0,7650

# %%
summary(ng_travel)$coefficients
# Out:
#                Estimate   Std. Error t value   Pr(>|t|)
# (Intercept)     7,3243070 1,45757204  5,025005 0,0015218730
# num_deliveries  0,5665008 0,07946339  7,129079 0,0001887842
# gas_price      -0,7649871 0,44378711 -1,723770 0,1284100014

# %%
library(car)
# Out:
# Error in library(car): there is no package called ‘car’
# Traceback:
#
# 1. library(car)
# 2. stop(txt, domain = NA)

# %%
caret::
# Out:
# Error: 'vif' is not an exported object from 'namespace:caret'
# Traceback:
#
# 1. caret::vif
# 2. getExportedValue(pkg, name)
# 3. stop(gettextf("'%s' is not an exported object from 'namespace:%s'",
#  .     name, getNamespaceName(ns)), call. = FALSE, domain = NA)

# %%
full_model = lm ( travel_time ~ miles_traveled + num_deliveries + gas_price)

# %%
full_model
# Out:
# Call:
# lm(formula = travel_time ~ miles_traveled + num_deliveries +
#     gas_price)
#
# Coefficients:
#    (Intercept)  miles_traveled  num_deliveries       gas_price
#        6,21138         0,01412         0,38315        -0,60655

# %%
summary(full_model)
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduzidos por coerção”
# Call:
# lm(formula = travel_time ~ miles_traveled + num_deliveries +
#     gas_price)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0,3183 -0,2123 -0,1218  0,2756  0,4304
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     6,21138    2,32057   2,677   0,0367 *
# miles_traveled  0,01412    0,02221   0,636   0,5483
# num_deliveries  0,38315    0,30006   1,277   0,2488
# gas_price      -0,60655    0,52663  -1,152   0,2932
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 0,3447 on 6 degrees of freedom
# Multiple R-squared:  0,8947,	Adjusted R-squared:  0,842
# F-statistic: 16,99 on 3 and 6 DF,  p-value: 0,002452

# %%
PRESS <- function(linear.model) {
  #' calculate the predictive residuals
  pr <- residuals(linear.model)/(1-lm.influence(linear.model)$hat)
  #' calculate the PRESS
  PRESS <- sum(pr^2)
  
  return(PRESS)
}

pred_r_squared <- function(linear.model) {
  #' Use anova() to get the sum of squares for the linear model
  lm.anova <- anova(linear.model)
  #' Calculate the total sum of squares
  tss <- sum(lm.anova$'Sum Sq')
  # Calculate the predictive R^2
  pred.r.squared <- 1-PRESS(linear.model)/(tss)
  
  return(pred.r.squared)
}

# %%
pred_r_squared(d)
# Out:
# [1] 0,7906725

# %%
# IMPORTANTE: Explica o código das duas células acima: 
# https://rpubs.com/RatherBit/102428
